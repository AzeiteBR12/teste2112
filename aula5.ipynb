# %%
print ("Vamos calcular a média da nota")
n1=(float(input("Digite a primeira nota:")))
n2=(float(input ("Digite a segunda nota:")))
n1=n1*7
n2=n2*3
media=(n1+n2)/10
print(media)
# Out:
# Vamos calcular a média da nota
# Digite a primeira nota:70
# Digite a segunda nota:50
# 64.0
