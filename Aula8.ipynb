# %%
## Seja bem vindo ao codigo
print ("Seja bem vindo ao meu primeiro código")
print (2+2)
## Que raiva desse negócio
print (2*(5+5))
variavel_de_teste1 = 12
variavel_de_teste2 = 2112
print ("teste de variavel 1, resultado do teste=", variavel_de_teste1)
print ("teste de variavel 2, resultado do teste=", variavel_de_teste2)
## Por qual motivo tem que ser virgula? Um simbolo de adicao faz mais sentido
print (" ")

##Atividade
print ("Atividade")
nome = input ("Deixa eu ver se seu nome é interessante, qual é seu nome? ")
print ("Definitivamente", nome, "é interessante")

##Pergunta2
print ("Vamos calcular os KM/L de seu carro")
KM = float(input ("Quantos KM seu carro rodou?"))
Combustivel = float(input ("quantos litros ele rodou?"))
print ("Seu carro faz", KM/Combustivel, "KM/L")
# Out:
# Seja bem vindo ao meu primeiro código
# 4
# 20
# teste de variavel 1, resultado do teste= 12
# teste de variavel 2, resultado do teste= 2112
#
# Atividade
# Deixa eu ver se seu nome é interessante, qual é seu nome? Tomas Urbano
# Definitivamente Tomas Urbano é interessante
# Vamos calcular os KM/L de seu carro
# Quantos KM seu carro rodou?12
# quantos litros ele rodou?2
# Seu carro faz 6.0 KM/L
